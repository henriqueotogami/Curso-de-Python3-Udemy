# %% [markdown]
# # Regressão Linear
# ## Least Squares Method

# %%
import pandas as pd

publi = pd.read_csv('https://raw.githubusercontent.com/XMUR/ISLR-1/master/Advertising.csv', index_col=0)
publi.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
print(publi.shape)
# Out:
# (200, 4)

# %%
x = publi[['TV', 'Radio', 'Newspaper']]
y = publi['Sales']

# %%
x.shape
# Out:
# (200, 3)

# %%
y.shape
# Out:
# (200,)

# %%
import seaborn as sns
sns.pairplot(publi, x_vars=['TV', 'Radio', 'Newspaper'], y_vars='Sales', height = 7, kind='reg')

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.3)

# %% [markdown]
# ## Importação do modelo de regressão linear

# %%
from sklearn.linear_model import LinearRegression
reglin = LinearRegression()
reglin.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# ## Coeficiente: Aumento nas vendas para cada 1un  investida em publicidade

# %%
list(zip(['TV', 'Radio', 'Newspaper'], reglin.coef_))
# Out:
# [('TV', 0.04706748223731438),
#  ('Radio', 0.18810467304256887),
#  ('Newspaper', 0.007078050734927515)]

# %% [markdown]
# ## Previsão

# %%
y_prev = reglin.predict(x_test)
print(y_prev)
# Out:
# [18.76795683 19.4687759  12.64127608 17.39017767 24.45729014 16.5215972
#  13.38532078 14.89281325 15.83477269 11.37999288 22.11136175 15.19944655
#  10.82228575 12.30885337 15.67304609 11.10945233 12.64231311 10.26828044
#  23.33930261  9.57435356  9.8020595  13.67705913 11.92908501  7.32269884
#  14.77971584  9.88688849 10.10808578 16.28649836 25.02978353  9.8113183
#   6.43022391 13.35163048  8.57225367 11.97487344  4.24445556  6.58324112
#  15.31130938 14.13176174 21.6894116  18.62332387 14.956023   18.59100177
#  20.01862481  6.34254681 18.37062214 23.99579335 13.61939509  3.37564065
#  19.47273025  7.87015867 16.45218243 13.70270307  6.3538112  16.50727307
#   9.54352948 11.85883082  7.50601665 17.2669148  14.51210477 17.92311093]

# %% [markdown]
# # Avaliação da performance
# ## MAE(Mean absolute error)

# %%
from sklearn import metrics

# %%
print(metrics.mean_absolute_error(y_test, y_prev))
# Out:
# 1.3417957189822123

# %% [markdown]
# ## MSE (Mean squared error)

# %%
print(metrics.mean_squared_error(y_test, y_prev))
# Out:
# 3.011399700731485

# %% [markdown]
# # RMSE (Root mean squared error)

# %%
import numpy as np
print(np.sqrt(metrics.mean_squared_error(y_test,y_prev)))
# Out:
# 1.735338497449845
